# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root / "src"))

# %%
from pangya_physics import CLUBS, Wind, find_velocity_for_distance

# %%
club = CLUBS["1W"]
wind = Wind(speed=0, degree=0)

result = find_velocity_for_distance(
    target_distance=200,
    club=club,
    wind=wind,
)

result
# Out:
# SolverResult(target_distance=200, velocity_z=111.5234375, final_distance=199.9426311421701, error=-0.05736885782991408)
